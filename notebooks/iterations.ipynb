# %%
for i in range(10):
    print(f"Iteration: {i}")
# Out:
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# Iteration: 6
# Iteration: 7
# Iteration: 8
# Iteration: 9

# %%
print("Trabajo finalizado")
